# %%
import os
import glob
import re
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# %%
pwd
# Out:
# '/Users/jeffliao/Desktop/dsc180a/project/notebooks'

# %%
apps = [i for i in os.listdir('../data/smali') if i[0] != '.']

# %%
# get all filenames with .smali using glob recursive=True
num_smali = list()
for app in apps:
    smali = glob.glob('../data/smali/%s/**/*.smali'%app, recursive=True)
    num_smali.append(len(smali))

# %%
pd.Series(num_smali).plot(kind='hist')
plt.title('Smali files in App')
plt.xlabel('Number of smali files');
plt.ylabel('Number of apps');
plt.savefig('./numSmali_per_app.png')

# %%
pd.Series(num_smali).describe()
# Out:
# count       50.000000
# mean      4404.840000
# std       3791.097953
# min         37.000000
# 25%       1257.750000
# 50%       3842.000000
# 75%       6061.250000
# max      14829.000000
# dtype: float64

# %%
smali[0]
# Out:
# '../data/smali/business-433/smali_classes2/okio/Okio$1.smali'

# %%
def find_api_calls(iterable, var):
    '''
    Find api calls in a list of texts and save the api calls into var
    input: iterable (list of texts), var (list to save to)
    '''
    for i in iterable:
        if('invoke-' in i and 'method' not in i):
            api_call = re.search('L.+', i).group(0)[1:]
            var.append(api_call)

# %%
calls = list()
for path in smali:
    with open(path) as f:
        # find api calls
        find_api_calls(f, calls)

# %%
fig= plt.figure(figsize=(20,6))
pd.Series(calls).value_counts().iloc[:50].plot(kind='bar');

plt.title('Count of APIs');
plt.xlabel('APIs');
plt.ylabel('Counts');
plt.savefig('./candy_crush.png')

# %%
pd.Series(calls).value_counts().iloc[:50]
# Out:
# java/lang/Object;-><init>()V                                                                                                                5242
# java/lang/StringBuilder;->append(Ljava/lang/String;)Ljava/lang/StringBuilder;                                                               4554
# java/lang/StringBuilder;->toString()Ljava/lang/String;                                                                                      1791
# java/lang/String;->valueOf(Ljava/lang/Object;)Ljava/lang/String;                                                                            1068
# java/lang/StringBuilder;-><init>()V                                                                                                         1058
# java/lang/String;->length()I                                                                                                                1022
# java/lang/String;->equals(Ljava/lang/Object;)Z                                                                                               931
# com/google/android/gms/internal/ads/zzdtt;->get()Ljava/lang/Object;                                                                          903
# java/util/Iterator;->next()Ljava/lang/Object;                                                                                                754
# java/lang/Integer;->valueOf(I)Ljava/lang/Integer;                                                                                            749
# java/util/Iterator;->hasNext()Z                                                                                                              746
# java/lang/StringBuilder;-><init>(I)V                                                                                                         707
# android/os/Parcel;->recycle()V                                                                                                               672
# java/lang/StringBuilder;->append(I)Ljava/lang/StringBuilder;                                                                                 657
# android/os/Bundle;->putString(Ljava/lang/String;Ljava/lang/String;)V                                                                         522
# java/util/List;->size()I                                                                                                                     508
# android/os/Parcel;->writeNoException()V                                                                                                      505
# java/lang/IllegalArgumentException;-><init>(Ljava/lang/String;)V                                                                             488
# java/util/ArrayList;-><init>()V                                                                                                              486
# com/google/android/gms/internal/ads/zzfm;->obtainAndWriteInterfaceToken()Landroid/os/Parcel;                                                 466
# java/util/List;->add(Ljava/lang/Object;)Z                                                                                                    423
# com/google/android/gms/internal/ads/zzdtg;->zzao(Lcom/google/android/gms/internal/ads/zzdtt;)Lcom/google/android/gms/internal/ads/zzdtt;     415
# java/util/ArrayList;->size()I                                                                                                                407
# java/util/List;->get(I)Ljava/lang/Object;                                                                                                    391
# android/os/Parcel;->writeInt(I)V                                                                                                             386
# java/lang/StringBuilder;->append(Ljava/lang/Object;)Ljava/lang/StringBuilder;                                                                376
# java/util/Map;->get(Ljava/lang/Object;)Ljava/lang/Object;                                                                                    372
# java/util/Map;->put(Ljava/lang/Object;Ljava/lang/Object;)Ljava/lang/Object;                                                                  371
# java/lang/Object;->getClass()Ljava/lang/Class;                                                                                               366
# java/lang/String;->concat(Ljava/lang/String;)Ljava/lang/String;                                                                              365
# java/util/ArrayList;->get(I)Ljava/lang/Object;                                                                                               357
# java/lang/Boolean;->booleanValue()Z                                                                                                          347
# java/lang/String;-><init>(Ljava/lang/String;)V                                                                                               344
# android/os/Bundle;-><init>()V                                                                                                                342
# android/text/TextUtils;->isEmpty(Ljava/lang/CharSequence;)Z                                                                                  340
# java/lang/IllegalStateException;-><init>(Ljava/lang/String;)V                                                                                329
# android/os/Parcel;->writeString(Ljava/lang/String;)V                                                                                         322
# org/json/JSONObject;->put(Ljava/lang/String;Ljava/lang/Object;)Lorg/json/JSONObject;                                                         312
# java/lang/Integer;->intValue()I                                                                                                              308
# com/google/android/gms/internal/ads/zzyr;->zzpe()Lcom/google/android/gms/internal/ads/zzacq;                                                 308
# com/google/android/gms/internal/ads/zzacq;->zzd(Lcom/google/android/gms/internal/ads/zzaci;)Ljava/lang/Object;                               307
# android/os/Parcel;->readString()Ljava/lang/String;                                                                                           306
# android/util/Log;->w(Ljava/lang/String;Ljava/lang/String;)I                                                                                  304
# android/os/Parcel;->readStrongBinder()Landroid/os/IBinder;                                                                                   300
# java/util/ArrayList;->add(Ljava/lang/Object;)Z                                                                                               295
# android/os/Parcel;->readInt()I                                                                                                               292
# java/lang/System;->arraycopy(Ljava/lang/Object;ILjava/lang/Object;II)V                                                                       281
# com/google/android/gms/internal/ads/zzdtr;->zzaq(Lcom/google/android/gms/internal/ads/zzdtt;)Lcom/google/android/gms/internal/ads/zzdtr;     271
# com/google/android/gms/internal/ads/zzcyw;->zzamw()Lcom/google/android/gms/internal/ads/zzcyw;                                               271
# com/google/android/gms/internal/ads/zzfm;->zza(ILandroid/os/Parcel;)V                                                                        261
# dtype: int64

# %%
calls = dict()
for path in smali:
    with open(path) as f:
        for line in f:
            # find api calls
            if('invoke' in line):
                api = re.search('\/{1}\w+;', line)
                if(api):
                    api = api.group(0)[1:-1]
                    try:
                        calls[api] += 1
                    except:
                        calls[api] = 1

# %%
{k: v for k, v in sorted(calls.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'StringBuilder': 9612,
#  'Object': 6797,
#  'String': 6656,
#  'Parcel': 4244,
#  'Bundle': 2494,
#  'View': 2096,
#  'ArrayList': 2067,
#  'List': 2021,
#  'Iterator': 1529,
#  'JSONObject': 1396,
#  'Context': 1374,
#  'Log': 1334,
#  'SafeParcelReader': 1304,
#  'Integer': 1279,
#  'Map': 1179,
#  'SafeParcelWriter': 1024,
#  'zzfm': 1015,
#  'Intent': 1006,
#  'Class': 966,
#  'zzdtt': 903,
#  'Math': 823,
#  'RecyclerView': 706,
#  'Preconditions': 638,
#  'zzaxa': 605,
#  'zzbae': 597,
#  'ByteBuffer': 593,
#  'Set': 564,
#  'Boolean': 555,
#  'IllegalArgumentException': 548,
#  'zzdnh': 535,
#  'zztv': 529,
#  'zzk': 523,
#  'IBinder': 518,
#  'Handler': 514,
#  'zzdpn': 508,
#  'Long': 501,
#  'zzdtr': 501,
#  'Utility': 498,
#  'zzfo': 497,
#  'zzvz': 482,
#  'zzdqy': 471,
#  'zzxj': 466,
#  'Activity': 465,
#  'Drawable': 457,
#  'zzdoa': 457,
#  'HashMap': 442,
#  'zzdtg': 433,
#  'Uri': 425,
#  'System': 420,
#  'zzyr': 416,
#  'CharSequence': 412,
#  'Unsafe': 412,
#  'PrintWriter': 411,
#  'zzbha': 411,
#  'IllegalStateException': 407,
#  'TypedArray': 405,
#  'TextUtils': 392,
#  'Resources': 385,
#  'Fragment': 380,
#  'zzaci': 377,
#  'MotionEvent': 373,
#  'zzst': 363,
#  'TextView': 357,
#  'JSONArray': 345,
#  'ViewGroup': 343,
#  'File': 336,
#  'zzbkd': 322,
#  'ViewPager': 314,
#  'zzacq': 313,
#  'UnsupportedOperationException': 312,
#  'NestedScrollView': 310,
#  'Collections': 308,
#  'Toolbar': 305,
#  'Logging': 304,
#  'WeakReference': 303,
#  'IabHelper': 299,
#  'FragmentManagerImpl': 284,
#  'zzcyw': 284,
#  'zza': 283,
#  'ViewCompat': 280,
#  'FrameLayout': 279,
#  'zzdtn': 273,
#  'StaggeredGridLayoutManager': 268,
#  'MenuBuilder': 267,
#  'zzdnc': 266,
#  'LinearLayoutManager': 263,
#  'zztq': 260,
#  'ObjectWrapper': 257,
#  'FacebookSdk': 257,
#  'Arrays': 255,
#  'OrientationHelper': 251,
#  'Method': 250,
#  'SparseArray': 247,
#  'Rect': 247,
#  'TintTypedArray': 244,
#  'HttpURLConnection': 241,
#  'ActivityHelper': 240,
#  'Task': 236,
#  'Enum': 234,
#  'FacebookException': 234,
#  'ArrayMap': 231,
#  'zzc': 231,
#  'zzsy': 226,
#  'Double': 222,
#  'DrawerLayout': 220,
#  'Canvas': 211,
#  'LinearLayoutCompat': 208,
#  'HashSet': 205,
#  'GraphRequest': 204,
#  'ImageView': 201,
#  'zzbas': 201,
#  'zzdqc': 201,
#  'zzwn': 201,
#  'AccessibilityNodeInfo': 197,
#  'AccessibilityNodeInfoCompat': 193,
#  'Thread': 185,
#  'LikeActionController': 181,
#  'Exception': 180,
#  'Lock': 176,
#  'zzkm': 170,
#  'AccessToken': 170,
#  'zzbys': 166,
#  'zzd': 163,
#  'IOException': 162,
#  'zzea': 162,
#  'Float': 161,
#  'zzaxj': 159,
#  'SharedPreferences': 157,
#  'WebView': 156,
#  'SearchView': 156,
#  'zzdmq': 154,
#  'zzdmm': 154,
#  'PackageManager': 153,
#  'AppCompatDelegateImplV9': 146,
#  'Logger': 146,
#  'zzr': 145,
#  'NullPointerException': 144,
#  'AtomicBoolean': 143,
#  'Looper': 143,
#  'Paint': 143,
#  'KeyEvent': 142,
#  'zzxy': 141,
#  'AbstractSafeParcelable': 140,
#  'zzdrn': 139,
#  'RemoteViews': 138,
#  'ViewDragHelper': 137,
#  'RuntimeException': 136,
#  'ConnectionResult': 135,
#  'zzdoj': 134,
#  'IabResult': 134,
#  'Field': 133,
#  'MenuItemImpl': 133,
#  'zzbbs': 131,
#  'Bitmap': 130,
#  'Throwable': 129,
#  'Cursor': 129,
#  'Validate': 129,
#  'zzdpj': 126,
#  'zzdro': 126,
#  'DecorToolbar': 123,
#  'Collection': 121,
#  'SlidingPaneLayout': 120,
#  'Player': 120,
#  'BigInteger': 117,
#  'Popup': 116,
#  'AtomicInteger': 114,
#  'SimpleArrayMap': 114,
#  'FastParser': 114,
#  'AtomicReference': 113,
#  'BaseGmsClient': 111,
#  'GooglePlayIABv3Lib': 111,
#  'zzcxw': 110,
#  'GameActivity': 110,
#  'Message': 109,
#  'Objects': 109,
#  'Clock': 109,
#  'JsonWriter': 108,
#  'Window': 107,
#  'ActionBarContextView': 107,
#  'zzq': 107,
#  'zzawn': 107,
#  'GoogleApiManager': 107,
#  'zzdy': 106,
#  'zzb': 105,
#  'zze': 105,
#  'SwipeRefreshLayout': 104,
#  'zzdrh': 103,
#  'MenuItem': 102,
#  'JsonReader': 102,
#  'zzavh': 101,
#  'Path': 100,
#  'zzbhn': 100,
#  'SparseArrayCompat': 99,
#  'Byte': 99,
#  'FastJsonResponse': 98,
#  'GraphResponse': 98,
#  'Character': 97,
#  'Status': 97,
#  'zzsk': 97,
#  'zzlc': 97,
#  'ActionBarOverlayLayout': 96,
#  'ChildHelper': 95,
#  'SparseIntArray': 95,
#  'zzazu': 95,
#  'Executor': 94,
#  'GridLayoutManager': 94,
#  'FragmentActivity': 93,
#  'GeneralSecurityException': 93,
#  'ActionMenuView': 92,
#  'SwitchCompat': 92,
#  'SystemClock': 92,
#  'zzwk': 92,
#  'LoginClient': 92,
#  'LayoutInflater': 91,
#  'StringBuffer': 91,
#  'zzdtp': 91,
#  'zzdpz': 91,
#  'zzta': 91,
#  'zzay': 90,
#  'GoogleApiClient': 89,
#  'zzbkg': 89,
#  'Runnable': 88,
#  'Dialog': 88,
#  'PopupWindow': 88,
#  'ShareInternalUtility': 88,
#  'Queue': 87,
#  'PendingIntent': 86,
#  'zzdmk': 86,
#  'ComponentName': 85,
#  'Date': 85,
#  'zzamw': 85,
#  'zzuv': 85,
#  'zaak': 85,
#  'LoginManager': 85,
#  'AdSize': 84,
#  'zztt': 84,
#  'zzdnf': 84,
#  'MediaPlayer': 84,
#  'ViewPropertyAnimatorCompat': 83,
#  'zzxs': 83,
#  'UUID': 83,
#  'zzwo': 83,
#  'AppEventsLoggerImpl': 83,
#  'AppCompatBackgroundHelper': 82,
#  'zzdqd': 82,
#  'ShareContent': 82,
#  'TypedValue': 81,
#  'FirebaseInstanceId': 81,
#  'zzu': 81,
#  'WebDialog': 81,
#  'RemoteException': 80,
#  'zax': 80,
#  'LoginButton': 80,
#  'NotificationSchedulerKeys': 80,
#  'zzaaz': 78,
#  'DynamicLoaderFactory': 78,
#  'zzbtr': 77,
#  'AdapterHelper': 76,
#  'zzh': 76,
#  'AppCompatTextHelper': 75,
#  'Matcher': 75,
#  'zzp': 75,
#  'ActionBarContainer': 74,
#  'ListPopupWindow': 74,
#  'FragmentHostCallback': 74,
#  'MapCollections': 74,
#  'TypedArrayUtils': 74,
#  'zzs': 74,
#  'zas': 74,
#  'WindowDecorActionBar': 73,
#  'ScrollingTabContainerView': 73,
#  'DefaultItemAnimator': 73,
#  'DropDownListView': 73,
#  'VelocityTracker': 73,
#  'zzbbi': 73,
#  'zzdtl': 73,
#  'zzdoi': 73,
#  'AppCompatDrawableManager': 72,
#  'NoSuchMethodError': 72,
#  'zzbhb': 72,
#  'URL': 71,
#  'WeakHashMap': 71,
#  'SupportMenuItem': 71,
#  'TaskCompletionSource': 71,
#  'zzaxc': 71,
#  'zzwh': 71,
#  'zzbfu': 71,
#  'OutputStream': 71,
#  'zzkh': 71,
#  'zzmh': 71,
#  'Locale': 70,
#  'IMediaSession': 70,
#  'zzf': 70,
#  'zzpe': 70,
#  'BasePendingResult': 70,
#  'InputStream': 69,
#  'RectF': 69,
#  'LinearLayout': 69,
#  'zzbkl': 69,
#  'GraphRequestBatch': 69,
#  'Pattern': 68,
#  'zzbdr': 68,
#  'FragmentManager': 67,
#  'FacebookRequestError': 67,
#  'NativeProtocol': 67,
#  'ListView': 66,
#  'IntentFilter': 66,
#  'ActionMenuPresenter': 66,
#  'FileOutputStream': 66,
#  'Binder': 66,
#  'zzaay': 66,
#  'zzbip': 66,
#  'zzbde': 66,
#  'XmlPullParser': 65,
#  'DrawableCompat': 65,
#  'CircleImageView': 65,
#  'FirebaseApp': 65,
#  'Api': 65,
#  'MediaFormat': 65,
#  'ActivityChooserView': 64,
#  'ActivityChooserModel': 64,
#  'RemoteCallbackList': 64,
#  'PlatformVersion': 64,
#  'ConcurrentHashMap': 64,
#  'zzbjn': 64,
#  'zzbdg': 64,
#  'zzbuy': 64,
#  'zzfn': 64,
#  'zzczk': 64,
#  'zzty': 64,
#  'DeviceAuthDialog': 64,
#  'VectorDrawableCompat': 63,
#  'zzan': 63,
#  'GoogleApiAvailability': 63,
#  'ShareContentValidation': 63,
#  'Messenger': 62,
#  'AssertionError': 62,
#  'zzo': 62,
#  'FragmentWrapper': 62,
#  'DataHolder': 62,
#  'CopyOnWriteArrayList': 61,
#  'zzya': 61,
#  'zzbxw': 61,
#  'zzxz': 61,
#  'FacebookButtonBase': 61,
#  'ThreadLocal': 60,
#  'AccessibilityEvent': 60,
#  'Base64': 60,
#  'zzlr': 60,
#  'MediaCodec': 60,
#  'zzkq': 60,
#  'ShareDialog': 60,
#  'AlertController': 59,
#  'ActionMode': 59,
#  'ArraySet': 59,
#  'CircularProgressDrawable': 59,
#  'CountDownLatch': 59,
#  'zzwv': 59,
#  'zzgr': 59,
#  'GameView': 59,
#  'ViewConfiguration': 58,
#  'ItemTouchHelper': 58,
#  'zzm': 58,
#  'zzg': 58,
#  'zzazy': 58,
#  'zzui': 58,
#  'InternalAppEventsLogger': 58,
#  'BillingScheduler': 58,
#  'ExploreByTouchHelper': 57,
#  'zaa': 57,
#  'zzdnu': 57,
#  'ActivityLifecycleTracker': 57,
#  'MusicManager': 57,
#  'ViewPropertyAnimator': 56,
#  'AppCompatTextViewAutoSizeHelper': 56,
#  'MenuPopupWindow': 56,
#  'GoogleApi': 56,
#  'zzno': 56,
#  'zzte': 56,
#  'DynamicLoader': 56,
#  'OverScroller': 55,
#  'Stack': 55,
#  'zzbce': 55,
#  'zzdnr': 55,
#  'AudioTrack': 55,
#  'SharePhoto': 55,
#  'LikeView': 55,
#  'AlertDialog': 54,
#  'ViewTreeObserver': 54,
#  'NestedScrollingChildHelper': 54,
#  'PagerAdapter': 54,
#  'PagerTitleStrip': 54,
#  'NativeAdView': 54,
#  'zzvf': 54,
#  'SafeParcelResponse': 54,
#  'FragmentTransitionCompat21': 53,
#  'BackStackRecord': 53,
#  'FragmentTransition': 53,
#  'zzaf': 53,
#  'zzbym': 53,
#  'zzdqs': 53,
#  'zzxd': 53,
#  'FacebookSdkWrapper': 53,
#  'WebSettings': 52,
#  'IndexOutOfBoundsException': 52,
#  'LinkedList': 52,
#  'zzi': 52,
#  'GoogleSignInOptions': 52,
#  'zzazd': 52,
#  'zzzi': 52,
#  'zzdoc': 52,
#  'zzbiw': 52,
#  'zzuf': 52,
#  'zzsu': 52,
#  'AdProviderGoogleMediaView': 52,
#  'Matrix': 51,
#  'FileInputStream': 51,
#  'AccessibilityRecord': 51,
#  'zzak': 51,
#  'zzaz': 51,
#  'zzbcp': 51,
#  'zzbel': 51,
#  'zabe': 51,
#  'AccessibilityDelegateCompat': 50,
#  'zzaax': 50,
#  'GoogleSignInAccount': 50,
#  'zzbcr': 50,
#  'zzdpw': 50,
#  'ShareApi': 50,
#  'AppCompatSpinner': 49,
#  'zzn': 49,
#  'GoogleApiAvailabilityLight': 49,
#  'GcmTaskService': 49,
#  'AppCall': 49,
#  'Color': 48,
#  'DocumentsContractApi19': 48,
#  'zzaxd': 48,
#  'ActionBar': 47,
#  'FragmentTransaction': 47,
#  'AudioManager': 47,
#  'FragmentController': 47,
#  'EdgeEffect': 47,
#  'zzbfb': 47,
#  'zzbjc': 47,
#  'zzbkt': 47,
#  'BlockingQueue': 47,
#  'zzuq': 47,
#  'AccessTokenManager': 47,
#  'FacebookDialogBase': 47,
#  'WebDialogFragment': 47,
#  'Button': 46,
#  'ByteArrayOutputStream': 45,
#  'AppCompatDelegate': 45,
#  'PlaybackStateCompat': 45,
#  'zzlh': 45,
#  'zzbkq': 45,
#  'WindowInsets': 44,
#  'LinkedHashMap': 44,
#  'zzt': 44,
#  'MessageDigest': 44,
#  'zzbio': 44,
#  'zzgk': 44,
#  'ImageManager': 44,
#  'NativeAdBaseApi': 44,
#  'VideoInterface': 44,
#  'Cipher': 43,
#  'ParcelFileDescriptor': 43,
#  'VectorDrawableCommon': 43,
#  'zzal': 43,
#  'zzyf': 43,
#  'zzdqt': 43,
#  'zzth': 43,
#  'zzhq': 43,
#  'BufferedReader': 43,
#  'VideoItem': 43,
#  'DialogFragment': 42,
#  'ViewParent': 42,
#  'Spinner': 42,
#  'EdgeEffectCompat': 42,
#  'CompoundButton': 42,
#  'zzw': 42,
#  'zzl': 42,
#  'zab': 42,
#  'zzuc': 42,
#  'zzcxy': 42,
#  'zzdqa': 42,
#  'zzdno': 42,
#  'zzdot': 42,
#  'zzhp': 42,
#  'zzup': 42,
#  'AppCompatActivity': 41,
#  'SuggestionsAdapter': 41,
#  'Notification': 41,
#  'zzab': 41,
#  'zzj': 41,
#  'zzqt': 41,
#  'zzbz': 41,
#  'zzdgx': 41,
#  'CursorWindow': 41,
#  'ProfilePictureView': 41,
#  'AdProviderGMAAndroid': 41,
#  'LocalBroadcastManager': 40,
#  'UnifiedNativeAdMapper': 40,
#  'zzuo': 40,
#  'zzaqc': 40,
#  'zac': 40,
#  'zzdo': 40,
#  'GLES20': 40,
#  'PendingResult': 40,
#  'SimpleInputConnection': 40,
#  'HandlerThread': 39,
#  'ArrayIndexOutOfBoundsException': 39,
#  'zzlm': 39,
#  'zzzj': 39,
#  'UserSettingsManager': 39,
#  'Purchase': 39,
#  'AdProviderFacebookMediaView': 39,
#  'ToolbarWidgetWrapper': 38,
#  'ActionBarDrawerToggle': 38,
#  'RoundRectDrawableWithShadow': 38,
#  'ColorStateList': 38,
#  'ColorUtils': 38,
#  'BaseAdView': 38,
#  'RelativeLayout': 38,
#  'GooglePlayServicesUtilLight': 38,
#  'zzdob': 38,
#  'GmsLogger': 38,
#  'AttributionIdentifiers': 38,
#  'ShareLinkContent': 38,
#  'IabException': 38,
#  'MenuPopupHelper': 37,
#  'ListViewCompat': 37,
#  'Parcelable': 37,
#  'SortedList': 37,
#  'Pair': 37,
#  'Loader': 37,
#  'zzag': 37,
#  'zzabb': 37,
#  'zzdrq': 37,
#  'zzlo': 37,
#  'zzxm': 37,
#  'zaaw': 37,
#  'GameRequestContent': 37,
#  'SdkEvent': 37,
#  'AppCompatResources': 36,
#  'ActionMenuItemView': 36,
#  'Display': 36,
#  'RemoteInput': 36,
#  'LoaderManagerImpl': 36,
#  'NativeAdMapper': 36,
#  'zzaxp': 36,
#  'ClientSettings': 36,
#  'zzsx': 36,
#  'zzdad': 36,
#  'zzux': 36,
#  'Notifier': 36,
#  'AppLinkNavigation': 35,
#  'ContentResolver': 35,
#  'Animation': 35,
#  'LocaleListHelper': 35,
#  'MediaDescriptionCompat': 35,
#  'zzz': 35,
#  'Storage': 35,
#  'zzbpb': 35,
#  'zzdjt': 35,
#  'zzanb': 35,
#  'zzdrb': 35,
#  'ShareVideoContent': 35,
#  'AdRunnable': 35,
#  'MessageBus': 35,
#  'BroadcastReceiver': 34,
#  'ImageButton': 34,
#  'LifecycleRegistry': 34,
#  'MediaBrowserServiceCompat': 34,
#  'RatingCompat': 34,
#  'MediaMetadataCompat': 34,
#  'zzv': 34,
#  'LifecycleCallback': 34,
#  'DynamiteModule': 34,
#  'zzdce': 34,
#  'zzbbm': 34,
#  'zzatl': 34,
#  'zzod': 34,
#  'zzpz': 34,
#  'FetchedAppSettingsManager': 34,
#  'JSONException': 33,
#  'WindowManager': 33,
#  'AbsActionBarView': 33,
#  'ContextCompat': 33,
#  'BidiFormatter': 33,
#  'Iterable': 33,
#  'UnifiedNativeAdView': 33,
#  'zzbij': 33,
#  'zzto': 33,
#  'zzcze': 33,
#  'zzbc': 33,
#  'zzdox': 33,
#  'zzamu': 33,
#  'zzadg': 33,
#  'zal': 33,
#  'GmsClientEventManager': 33,
#  'zacm': 33,
#  'LikeBoxCountView': 33,
#  'Constructor': 32,
#  'AppCompatImageHelper': 32,
#  'AnimatedVectorDrawableCompat': 32,
#  'AutoScrollHelper': 32,
#  'zzau': 32,
#  'zad': 32,
#  'zzanm': 32,
#  'zzagf': 32,
#  'zzwl': 32,
#  'InstanceID': 32,
#  'VideoUploader': 32,
#  'SearchableInfo': 31,
#  'Signature': 31,
#  'AnimatorInflaterCompat': 31,
#  'Component': 31,
#  'zzao': 31,
#  'zzyb': 31,
#  'zzvl': 31,
#  'AdvertisingIdClient': 31,
#  'zzvq': 31,
#  'zzhj': 31,
#  'Wrappers': 31,
#  'zzane': 31,
#  'AbstractList': 31,
#  'FacebookCallback': 31,
#  'AdProviderGMAAndroidNoMultiFetch': 31,
#  'LinearSmoothScroller': 30,
#  'ViewInfoStore': 30,
#  'CascadingMenuPopup': 30,
#  'BaseFragmentActivityApi16': 30,
#  'zzar': 30,
#  'zzbqk': 30,
#  'ConcurrentMap': 30,
#  'zzdgq': 30,
#  'IOUtils': 30,
#  'zzdmh': 30,
#  'PackageManagerWrapper': 30,
#  'zzum': 30,
#  'zzdn': 30,
#  'zzdne': 30,
#  'DeviceShareDialogFragment': 30,
#  'WorkQueue': 30,
#  'ShareMessengerGenericTemplateElement': 30,
#  'Menu': 29,
#  'LongSparseArray': 29,
#  'ClassLoader': 29,
#  'ListAdapter': 29,
#  'ListMenuItemView': 29,
#  'Array': 29,
#  'Mac': 29,
#  'NotificationBuilderWithBuilderAccessor': 29,
#  'Animator': 29,
#  'DrawableWrapperApi14': 29,
#  'zzayj': 29,
#  'zzbco': 29,
#  'zzamt': 29,
#  'zzig': 29,
#  'zzdra': 29,
#  'zzks': 29,
#  'StackTraceElement': 29,
#  'zzagg': 29,
#  'zzeh': 29,
#  'zzxe': 29,
#  'ViewIndexer': 29,
#  'LoginLogger': 29,
#  'MessengerShareContentUtility': 29,
#  'AppCompatDialog': 28,
#  'ActionProvider': 28,
#  'ButtonBarLayout': 28,
#  'AlertDialogLayout': 28,
#  'Scroller': 28,
#  'Tasks': 28,
#  'zzat': 28,
#  'GmsClient': 28,
#  'zzbdl': 28,
#  'zzyq': 28,
#  'zzpd': 28,
#  'zzcaa': 28,
#  'DialogPresenter': 28,
#  'UserDataStore': 28,
#  'InAppPurchaseEventManager': 28,
#  'CodelessManager': 28,
#  'MessageDialog': 28,
#  'NativeApplication': 28,
#  'DrawerArrowDrawable': 27,
#  'AttributeSet': 27,
#  'PositionMap': 27,
#  'CardViewBaseImpl': 27,
#  'NotificationCompatJellybean': 27,
#  'Process': 27,
#  'RoundedBitmapDrawable': 27,
#  'AudioAttributesCompat': 27,
#  'zzdto': 27,
#  'zzaki': 27,
#  'zzdhl': 27,
#  'zzts': 27,
#  'zzdbs': 27,
#  'zzamx': 27,
#  'zzxl': 27,
#  'GcmNetworkManager': 27,
#  'AppEventsLogger': 27,
#  'MultithreadedBundleWrapper': 27,
#  'ViewHierarchy': 27,
#  'ShareMessengerMediaTemplateContent': 27,
#  'CursorAdapter': 26,
#  'WindowInsetsCompat': 26,
#  'AsyncTaskLoader': 26,
#  'MediaControllerCompatApi21': 26,
#  'Keyframe': 26,
#  'AbstractAdViewAdapter': 26,
#  'ConnectionTracker': 26,
#  'zae': 26,
#  'zzfk': 26,
#  'zzuh': 26,
#  'zzmw': 26,
#  'zzxx': 26,
#  'zzbj': 26,
#  'zzqj': 26,
#  'zzov': 26,
#  'zzhl': 26,
#  'WebLoginMethodHandler': 26,
#  'AppInviteDialog': 26,
#  'DeviceShareButton': 26,
#  'LikeDialog': 26,
#  'CandyCrushSagaActivity': 26,
#  'ExecutorService': 25,
#  'ContextThemeWrapper': 25,
#  'ContentFrameLayout': 25,
#  'ForwardingListener': 25,
#  'DrawableUtils': 25,
#  'LruCache': 25,
#  'ICustomTabsCallback': 25,
#  'Service': 25,
#  'MediationInterstitialListener': 25,
#  'zzy': 25,
#  'zzayc': 25,
#  'ConnectionErrorMessages': 25,
#  'Scope': 25,
#  'PendingResultUtil': 25,
#  'zzbbx': 25,
#  'zzws': 25,
#  'zzdsv': 25,
#  'zzdnt': 25,
#  'zzvj': 25,
#  'zzvp': 25,
#  'zzld': 25,
#  'zaj': 25,
#  'zak': 25,
#  'FileLruCache': 25,
#  'LoginBehavior': 25,
#  'ShareOpenGraphAction': 25,
#  'SharePhotoContent': 25,
#  'ShareOpenGraphContent': 25,
#  'ShareButtonBase': 25,
#  'ShareStoryContent': 25,
#  'KsdkCoreActivityHelper': 25,
#  'ScheduledExecutorService': 24,
#  'SupportMenu': 24,
#  'ContainerHelpers': 24,
#  'ModernAsyncTask': 24,
#  'ResultReceiver': 24,
#  'zzx': 24,
#  'zzai': 24,
#  'KeyPair': 24,
#  'PublisherAdView': 24,
#  'SignInHubActivity': 24,
#  'zzge': 24,
#  'zzani': 24,
#  'zzcga': 24,
#  'zzdh': 24,
#  'zzik': 24,
#  'zzcat': 24,
#  'zzkv': 24,
#  'zzbdh': 24,
#  'zzbiz': 24,
#  'zzdpd': 24,
#  'zzef': 24,
#  'zzok': 24,
#  'zzvv': 24,
#  'FetchedAppSettings': 24,
#  'NativeAppCallAttachmentStore': 24,
#  'LoginMethodHandler': 24,
#  'NativeDialogParameters': 24,
#  'ShareVideo': 24,
#  'FileHandle': 24,
#  'PlayerDialogFragment': 24,
#  'PopupDialog': 24,
#  'Executors': 23,
#  'ViewPropertyAnimatorCompatSet': 23,
#  'TraceCompat': 23,
#  'ProgressBar': 23,
#  'RoundRectDrawable': 23,
#  'MenuPopup': 23,
#  'SeekBar': 23,
#  'NotificationManager': 23,
#  'AudioAttributes': 23,
#  'IMediaControllerCallback': 23,
#  'zzaj': 23,
#  'Properties': 23,
#  'zzcfo': 23,
#  'zzdlw': 23,
#  'zzaaq': 23,
#  'zzcci': 23,
#  'zzdgk': 23,
#  'zzdfw': 23,
#  'zzie': 23,
#  'Feature': 23,
#  'ShareMessengerURLActionButton': 23,
#  'CancellationTokenSource': 22,
#  'ContextWrapper': 22,
#  'Location': 22,
#  'AbsSavedState': 22,
#  'SpannableStringBuilder': 22,
#  'ListFragment': 22,
#  'FocusStrategy': 22,
#  'PagerTabStrip': 22,
#  'PathParser': 22,
#  'MediaSessionCompatApi21': 22,
#  'zzabc': 22,
#  'DeferredLifecycleHelper': 22,
#  'zzdof': 22,
#  'zzasy': 22,
#  'zzbpc': 22,
#  'zzdkq': 22,
#  'zzmy': 22,
#  'zzbzb': 22,
#  'zzyh': 22,
#  'zzajs': 22,
#  'zzanh': 22,
#  'zzanc': 22,
#  'zzdbk': 22,
#  'zzczr': 22,
#  'FacebookDialogFragment': 22,
#  'AdInternalSettings': 22,
#  'AdComponentView': 22,
#  'PersistableBundle': 22,
#  'WebViewHelper': 22,
#  'AdProviderFacebookMediaViewController': 22,
#  'IntentField': 22,
#  'PrintStream': 21,
#  'DecorContentParent': 21,
#  'AccessibilityRecordCompat': 21,
#  'SimpleItemAnimator': 21,
#  'ThemeUtils': 21,
#  'ActivityOptionsCompat': 21,
#  'PrintAttributes': 21,
#  'TypefaceCompatApi26Impl': 21,
#  'VolumeProviderCompat': 21,
#  'MediationBannerListener': 21,
#  'zzas': 21,
#  'zzact': 21,
#  'Future': 21,
#  'zzdgt': 21,
#  'zzboc': 21,
#  'ConditionVariable': 21,
#  'zzdrm': 21,
#  'zzdpe': 21,
#  'zzbza': 21,
#  'zzbdj': 21,
#  'zzdea': 21,
#  'EGL10': 21,
#  'zzir': 21,
#  'CopyOnWriteArraySet': 21,
#  'zai': 21,
#  'Result': 21,
#  'AppEventQueue': 21,
#  'SessionInfo': 21,
#  'EventBinding': 21,
#  'ToolTipPopup': 21,
#  'AppInviteContent': 21,
#  'ShareFeedContent': 21,
#  'WebViewClient': 20,
#  'LinkedBlockingQueue': 20,
#  'NotificationCompat': 20,
#  'SubMenuBuilder': 20,
#  'TextPaint': 20,
#  'IInterface': 20,
#  'TransitionSet': 20,
#  'PathMeasure': 20,
#  'AdListener': 20,
#  'MediationNativeListener': 20,
#  'zzyd': 20,
#  'zzaqe': 20,
#  'zzxp': 20,
#  'GoogleSignInClient': 20,
#  'zzdbz': 20,
#  'zzdkw': 20,
#  'zzbpq': 20,
#  'SensorManager': 20,
#  'zzcfy': 20,
#  'zzsg': 20,
#  'zzanf': 20,
#  'zzdlm': 20,
#  'zzye': 20,
#  'zzddq': 20,
#  'AppMeasurementSdk': 20,
#  'zzmj': 20,
#  'zzyi': 20,
#  'FetchedAppGateKeepersManager': 20,
#  'AppEvent': 20,
#  'AdProviderStateMachineNativeFunctions': 20,
#  'ToolbarActionBar': 19,
#  'AppCompatDelegateImplV14': 19,
#  'ActionBarPolicy': 19,
#  'AppCompatCompoundButtonHelper': 19,
#  'SparseBooleanArray': 19,
#  'AsyncTask': 19,
#  'RemoteInputCompatJellybean': 19,
#  'ActivityOptions': 19,
#  'TypefaceCompatUtil': 19,
#  'MediaSession': 19,
#  'MediaController': 19,
#  'CustomEventAdapter': 19,
#  'zzaw': 19,
#  'zzavc': 19,
#  'Account': 19,
#  'zzbm': 19,
#  'zznm': 19,
#  'zzdgz': 19,
#  'zzapd': 19,
#  'zzdnn': 19,
#  'zzcxu': 19,
#  'zzdgi': 19,
#  'zzaew': 19,
#  'zzjg': 19,
#  'zzdhn': 19,
#  'MediaExtractor': 19,
#  'zzbjh': 19,
#  'StrictMode': 19,
#  'zzaev': 19,
#  'SignInButtonImpl': 19,
#  'Profile': 19,
#  'RewardedVideoAdApi': 19,
#  'ImageDownloader': 19,
#  'GameRequestDialog': 19,
#  'ShareMedia': 19,
#  'CrashReportDispatcher': 19,
#  'AppNotRespondingDetectorThread': 19,
#  'AppCompatDelegateImplBase': 18,
#  'TimeUnit': 18,
#  'Interpolator': 18,
#  'CardViewDelegate': 18,
#  'CancellationSignal': 18,
#  'RemoteInputCompatApi20': 18,
#  'SharedElementCallback': 18,
#  'FragmentTabHost': 18,
#  'ShortcutInfoCompat': 18,
#  'LinkifyCompat': 18,
#  'MediaBrowserCompatApi21': 18,
#  'FastSafeIterableMap': 18,
#  'VideoController': 18,
#  'ApiExceptionMapper': 18,
#  'Credential': 18,
#  'zzckz': 18,
#  'zzcgl': 18,
#  'zzbqx': 18,
#  'zzadh': 18,
#  'zzdgv': 18,
#  'zzdol': 18,
#  'MediaView': 18,
#  'zzdtj': 18,
#  'zzajv': 18,
#  'StringWriter': 18,
#  'zzbtu': 18,
#  'zzdk': 18,
#  'zzhs': 18,
#  'zzdfs': 18,
#  'zzdeg': 18,
#  'zzazt': 18,
#  'zzbhr': 18,
#  'DataOutputStream': 18,
#  'ContentValues': 18,
#  'zam': 18,
#  'LegacyTokenHelper': 18,
#  'ConcurrentLinkedQueue': 18,
#  'InstrumentUtility': 18,
#  'LikeButton': 18,
#  'ShareMessengerGenericTemplateContent': 18,
#  'ShareMessengerOpenGraphMusicTemplateContent': 18,
#  'AdProviderGoogleMediaViewController': 18,
#  'WebViewAppLinkResolver': 17,
#  'ThreadPoolExecutor': 17,
#  'URLConnection': 17,
#  'ViewUtils': 17,
#  'CardViewApi21Impl': 17,
#  'BaseMenuPresenter': 17,
#  'GravityCompat': 17,
#  'Typeface': 17,
#  'MenuAdapter': 17,
#  'StandardMenuPopup': 17,
#  'JobIntentService': 17,
#  'ValueAnimator': 17,
#  'SearchViewCompat': 17,
#  'FontsContractCompat': 17,
#  'FutureTask': 17,
#  'UnifiedNativeAd': 17,
#  'NativeAppInstallAdMapper': 17,
#  ...}

# %%
G = nx.Graph()

# %%
G.add_node(1)
G.add_nodes_from([2, 3])

# %%
G.add_edge(1, 2)
G.add_edge(1, 3)

# %%
nx.draw(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')

# %%
G.add_node(1)

nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')

# %%
G.add_edge(1, 2)
nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')

# %%
G.degree
# Out:
# DegreeView({1: 2, 2: 1, 3: 1})

# %%
G.add_edge(1, 2)
G.degree
# Out:
# DegreeView({1: 2, 2: 1, 3: 1})

# %%
relation = nx.Graph()
# relation.add_node('a')
relation.add_nodes_from(['a','b'])
pos=nx.spring_layout(relation)
nx.draw(relation, pos)
# nx.draw_shell(relation, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')

# %%
# with open(smali[0]) as f:
#     doc = f.read()  
#     the_class = re.search('\.class.+;{1}', doc).group(0)[8:-1]
#     the_super = re.search('\.super.+;{1}', doc).group(0)[8:-1]
#     relation.add_node(node)

# the_class
# the_super

# %%
# path are the smali files
for path in smali:
    with open(path) as f:
        # read the entire doc
        doc = f.read()
        # obtain the class and super part
        the_class = re.search('\.class.+;{1}', doc).group(0)[8:-1]
        the_super = re.search('\.super.+;{1}', doc).group(0)[8:-1]
        # both class and super are a "class", add to node
        relation.add_node(the_class)
        relation.add_node(the_super)
        # class inherits super so add an edge
        relation.add_edge(the_class, the_super)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-0c8c8f500eb3> in <module>
#       8         the_super = re.search('\.super.+;{1}', doc).group(0)[8:-1]
#       9         # both class and super are a "class", add to node
# ---> 10         relation.add_node(the_class)
#      11         relation.add_node(the_super)
#      12         # class inherits super so add an edge
#
# NameError: name 'relation' is not defined

# %%
relation.nodes
# Out:
# NodeView(('bolts/WebViewAppLinkResolver$2$1', 'android/webkit/WebViewClient', 'inal Lbolts/Task$14', 'java/lang/Object', 'inal Lbolts/Task$4', 'inal Lbolts/Task$6', 'ublic Lbolts/CancellationTokenSource', 'ublic final Lbolts/Bolts', 'inal Lbolts/Task$2', 'bolts/Task$12', 'bolts/BoltsExecutors$ImmediateExecutor', 'bolts/Task$10', 'bolts/CancellationTokenSource$1', 'ublic Lbolts/AppLink', 'bolts/WebViewAppLinkResolver$2$2', 'inal Lbolts/Task$7', 'ublic Lbolts/Task$TaskCompletionSource', 'inal Lbolts/Task$5', 'ynthetic Lbolts/AndroidExecutors$1', 'inal Lbolts/Task$15', 'bolts/Task$11', 'inal Lbolts/Task$1', 'ublic final Lbolts/AppLinks', 'ublic Lbolts/Capture', 'ublic Lbolts/AppLinkNavigation', 'inal Lbolts/AndroidExecutors', 'ublic interface abstract Lbolts/Continuation', 'ublic final enum Lbolts/AppLinkNavigation$NavigationResult', 'java/lang/Enum', 'bolts/Task$13', 'bolts/AndroidExecutors$UIThreadExecutor', 'bolts/Task$3', 'ynthetic Lbolts/BoltsExecutors$1', 'inal Lbolts/BoltsExecutors', 'ublic Lbolts/AggregateException', 'java/lang/Exception', 'ublic Lbolts/Task', 'ublic Lbolts/AppLink$Target', 'ublic Lbolts/MeasurementEvent', 'ublic Lbolts/CancellationToken', 'inal Lbolts/AppLinkNavigation$1', 'bolts/Task$9', 'bolts/WebViewAppLinkResolver$2', 'ublic Lbolts/WebViewAppLinkResolver', 'ublic interface abstract Lbolts/AppLinkResolver', 'ublic Lbolts/CancellationTokenRegistration', 'bolts/Task$15$1', 'bolts/WebViewAppLinkResolver$1', 'inal Lbolts/Task$8', 'bolts/WebViewAppLinkResolver$3', 'ublic final Landroid/support/coreutils/BuildConfig', 'ublic final Landroid/support/coreutils/R$bool', 'ublic final Landroid/support/coreutils/R', 'ublic final Landroid/support/coreutils/R$id', 'ublic final Landroid/support/coreutils/R$dimen', 'ublic final Landroid/support/coreutils/R$integer', 'ublic final Landroid/support/coreutils/R$color', 'ublic final Landroid/support/coreutils/R$drawable', 'ublic final Landroid/support/coreutils/R$layout', 'ublic final Landroid/support/coreutils/R$attr', 'ublic final Landroid/support/coreutils/R$style', 'ublic final Landroid/support/coreutils/R$string', 'ublic final Landroid/support/coreutils/R$styleable', 'ublic final Landroid/support/v7/BuildConfig', 'ublic final Landroid/support/v7/R', 'ublic final Landroid/support/v7/UnusedStubRecyclerView', 'android/support/v7/app/ToolbarActionBar', 'android/support/v7/app/ActionBar', 'ublic abstract Landroid/support/v7/app/AppCompatDelegate', 'ublic Landroid/support/v7/app/NotificationCompat$Builder', 'android/support/v4/app/NotificationCompat$Builder', 'android/support/v7/app/AppCompatDelegateImplBase$AppCompatWindowCallbackBase', 'android/support/v7/view/WindowCallbackWrapper', 'ublic Landroid/support/v7/app/AppCompatDialogFragment', 'android/support/v4/app/DialogFragment', 'android/support/v7/app/AppCompatDelegateImplN', 'android/support/v7/app/AppCompatDelegateImplV23', 'android/support/v7/app/AlertController', 'android/support/v7/app/ActionBarDrawerToggle$DummyDelegate', 'ublic interface abstract Landroid/support/v7/app/AlertController$AlertParams$OnPrepareListViewListener', 'android/support/v7/app/AppCompatDelegateImplV14$AppCompatWindowCallbackV14', 'ublic interface abstract annotation Landroid/support/v7/app/ActionBar$NavigationMode', 'ublic interface abstract annotation Landroid/support/v7/app/AppCompatDelegate$NightMode', 'inal Landroid/support/v7/app/AppCompatDelegateImplV9$PanelFeatureState$SavedState$1', 'inal Landroid/support/v7/app/AppCompatDelegateImplV9$PanelMenuPresenterCallback', 'android/support/v7/app/AppCompatDelegateImplV14', 'android/support/v7/app/AppCompatDelegateImplV11', 'android/support/v7/app/ActionBarDrawerToggle$HoneycombDelegate', 'ublic Landroid/support/v7/app/WindowDecorActionBar$TabImpl', 'android/support/v7/app/ActionBar$Tab', 'ublic Landroid/support/v7/app/WindowDecorActionBar', 'android/support/v7/app/AppCompatDelegateImplV9$5$1', 'android/support/v4/view/ViewPropertyAnimatorListenerAdapter', 'ublic Landroid/support/v7/app/AlertD ...

# %%
plt.figure(figsize=(30,50)) 
nx.draw(relation, node_size=60)
plt.savefig('candy_crush_relations.png')

# %%
pd.DataFrame(relation.degree).sort_values(by=1, ascending=False)
# Out:
#                                                       0     1
# 3                                      java/lang/Object  6403
# 28                                       java/lang/Enum   132
# 2230  com/google/android/gms/common/internal/safepar...   114
# 2936          com/google/android/gms/internal/ads/zzdoa    86
# 2912      com/google/android/gms/internal/ads/zzdoa$zza    85
# ...                                                 ...   ...
# 3282  ublic final Lcom/google/android/gms/internal/a...     1
# 3281  inal synthetic Lcom/google/android/gms/interna...     1
# 3280  inal synthetic Lcom/google/android/gms/interna...     1
# 3279  inal synthetic Lcom/google/android/gms/interna...     1
# 9362             com/king/store/billingutil/IabHelper$1     1
#
# [9363 rows x 2 columns]

# %%
relation.remove_node('java/lang/Object')

# %%
plt.figure(figsize=(20,40)) 
nx.draw(relation, node_size=60)
plt.savefig('candy_crush_relations.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-4ddfbbb5d75c> in <module>
#       1 plt.figure(figsize=(20,40))
# ----> 2 nx.draw(relation, node_size=60)
#       3 plt.savefig('candy_crush_relations.png')
#
# NameError: name 'relation' is not defined
